# %% [markdown]
# # Mean, Median, and Mode

# %%
import numpy

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

mean = numpy.mean(speed)

print(mean)

median = numpy.median(speed)

print(median)

from scipy import stats

mode  = stats.mode(speed)

print(mode)
# Out:
# 89.76923076923077
# 87.0
# ModeResult(mode=array([86]), count=array([3]))

# %% [markdown]
# # Standard Deviation and Variance

# %%
import numpy

speed = [86,87,88,86,87,85,86]

sd = numpy.std(speed)

var = numpy.var(speed)

print(sd)

print(var)
# Out:
# 0.9035079029052513
# 0.8163265306122449

# %% [markdown]
# # Percentile

# %%
import numpy

ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]

x = numpy.percentile(ages, 75)

print(x)
# Out:
# 43.0

# %% [markdown]
# # Data Distribution

# %%
import numpy

x = numpy.random.uniform(0.0, 5.0, 250)

print(x)
# Out:
# [0.61365842 4.8813864  0.60063365 1.51092807 3.44997022 0.30183875
#  4.27823431 2.68563983 3.65227329 4.14393411 1.5039201  2.20324373
#  1.88330361 1.96807762 0.55769019 1.51570806 1.54143019 1.91330273
#  4.21280855 0.77426927 4.7033407  0.7798747  3.84253903 0.10632978
#  0.18457286 4.87330512 2.94272955 4.03732029 2.27319749 4.86776618
#  1.98128666 4.19561595 3.15815164 0.26980962 1.24575793 1.74492094
#  0.12552428 3.87149566 4.81323942 0.60213237 0.23127755 1.03825524
#  0.6537336  3.79268285 1.65327984 2.37441439 1.6455535  2.24107036
#  0.42940082 4.11608261 3.78416979 1.8973529  1.76538771 2.25293398
#  3.59592602 3.22016917 4.62420607 4.90168367 0.52975436 4.8949861
#  2.02710112 0.56454398 4.58913828 4.48691775 4.98773473 2.14110402
#  4.73035304 4.37767364 1.20751323 2.0114074  4.4366584  4.49127447
#  4.46128372 3.25599985 1.02289702 2.64433013 4.80914191 4.26910967
#  4.22464312 1.75792922 3.64563414 2.61948411 2.51264083 4.91454395
#  1.69631287 2.59489371 1.2299018  2.3769744  0.64486629 4.22598925
#  0.40178956 3.27290263 3.64101675 3.69650464 0.99496657 0.97553357
#  0.78853169 0.36386026 1.36938169 1.34030213 1.37966396 3.40622702
#  0.58002356 0.33688874 3.77263362 4.72915667 4.4545785  3.01593026
#  4.55627106 4.27854609 2.57667409 0.54731106 0.7050173  4.97723514
#  3.50712266 0.1195111  2.90218697 4.07033965 2.4093849  1.52519161
#  1.91165308 1.81873069 2.90079421 1.07944125 3.43158144 0.06814274
#  2.16164546 1.66366141 3.97159259 3.89477983 1.34883347 3.59666653
#  3.27631549 2.14438087 0.05267103 3.02208224 4.24665901 4.54725226
#  3.09953905 2.80178967 3.73176034 2.87786182 1.42172421 3.83776347
#  2.13599197 2.72779004 4.91804165 2.43381018 1.35916759 3.23071022
#  3.91642958 1.82805209 4.08051391 2.12487784 3.6078651  1.08168698
#  3.05861522 0.06033562 0.47467826 0.21176566 4.08895165 2.68946762
#  4.51240636 2.40138578 4.44559842 0.72631702 0.6204745  3.21204609
#  3.30763826 0.98000467 0.16249424 0.84353722 3.64930099 2.88540134
#  0.66531318 4.15024153 4.0517281  0.9915333  2.20831241 4.65960567
#  0.10746148 0.11330554 2.03059043 3.34905725 3.37705098 3.41437632
#  0.20858326 0.33315481 1.65026911 1.99522956 0.2076561  4.57638221
#  3.81608763 4.64465529 4.03766315 1.15845374 1.52781785 1.92801987
#  0.81982473 2.8358244  0.09679278 0.57532282 2.11738282 1.02002643
#  3.90524915 2.98992533 2.20046396 1.52378976 4.92357595 1.2518304
#  2.23574774 3.57415606 2.25199024 2.41614544 1.1967061  1.36893015
#  3.6458963  3.13324357 4.69973235 4.61899738 4.2684586  3.12437786
#  4.92689619 0.28510796 2.20083443 2.75040917 0.21768667 0.5164613
#  3.91134371 3.38942546 3.02089913 4.04644543 2.00119065 2.72913849
#  2.35124834 0.11557714 0.67707362 2.24331233 4.56811862 0.44617018
#  2.01101582 0.48479484 1.39036128 1.65395996 3.8533533  3.32431926
#  1.62071916 2.05212678 2.36252667 4.76263039]

# %% [markdown]
# # Histogram

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 250)

plt.hist(x, 5)

plt.show()

# %% [markdown]
# # Big Data Distribution

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 5.0, 100000)

plt.hist(x, 100)

plt.show()

# %% [markdown]
# # Normal Data Distribution

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %% [markdown]
# # Random Data Distribution

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %% [markdown]
# # Linear Regression

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

print(r)
# Out:
# -0.758591524376155

# %% [markdown]
# # Polynomial Regression

# %%
import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# # R-Squared

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))

import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 0.9432150416451027
# 88.87331269697978

# %% [markdown]
# # Multiple Regression

# %%
import pandas

df = pandas.read_csv("cars.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, y)

#Predicted
predictedCO2 = regr.predict([[2300, 1300]])
print(predictedCO2)

#Coefficient
print(regr.coef_)
# Out:
# [107.2087328]
# [0.00755095 0.00780526]

# %% [markdown]
# # Scale

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

df = pandas.read_csv("cars.csv")

X = df[['Weight', 'Volume']]

scaledX = scale.fit_transform(X)

print(scaledX)
# Out:
# [[-2.10389253 -1.59336644]
#  [-0.55407235 -1.07190106]
#  [-1.52166278 -1.59336644]
#  [-1.78973979 -1.85409913]
#  [-0.63784641 -0.28970299]
#  [-1.52166278 -1.59336644]
#  [-0.76769621 -0.55043568]
#  [ 0.3046118  -0.28970299]
#  [-0.7551301  -0.28970299]
#  [-0.59595938 -0.0289703 ]
#  [-1.30803892 -1.33263375]
#  [-1.26615189 -0.81116837]
#  [-0.7551301  -1.59336644]
#  [-0.16871166 -0.0289703 ]
#  [ 0.14125238 -0.0289703 ]
#  [ 0.15800719 -0.0289703 ]
#  [ 0.3046118  -0.0289703 ]
#  [-0.05142797  1.53542584]
#  [-0.72580918 -0.0289703 ]
#  [ 0.14962979  1.01396046]
#  [ 1.2219378  -0.0289703 ]
#  [ 0.5685001   1.01396046]
#  [ 0.3046118   1.27469315]
#  [ 0.51404696 -0.0289703 ]
#  [ 0.51404696  1.01396046]
#  [ 0.72348212 -0.28970299]
#  [ 0.8281997   1.01396046]
#  [ 1.81254495  1.01396046]
#  [ 0.96642691 -0.0289703 ]
#  [ 1.72877089  1.01396046]
#  [ 1.30990057  1.27469315]
#  [ 1.90050772  1.01396046]
#  [-0.23991961 -0.0289703 ]
#  [ 0.40932938 -0.0289703 ]
#  [ 0.47215993 -0.0289703 ]
#  [ 0.4302729   2.31762392]]
# [97.07204485]

# %%
#Predicted Value
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

df = pandas.read_csv("cars.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']

scaledX = scale.fit_transform(X)

regr = linear_model.LinearRegression()
regr.fit(scaledX, y)

scaled = scale.transform([[2300, 1.3]])

predictedCO2 = regr.predict([scaled[0]])
print(predictedCO2)
# Out:
# [97.07204485]

# %% [markdown]
# # Train/Test

# %%
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

plt.scatter(x, y)
plt.show()

# %%
#Split into Train/Test
train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

# %%
#Display the Training Set
plt.scatter(train_x, train_y)
plt.show()

#Display the Testing Set
plt.scatter(test_x, test_y)
plt.show()

# %%
#Fit the Data set
mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

myline = numpy.linspace(0, 6, 100)

plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
#R-Squared
r2 = r2_score(train_y, mymodel(train_x))

print(r2)
# Out:
# 0.7988645544629793

# %%
#Predicted Value
print(mymodel(5))
# Out:
# 22.87962591812459

# %% [markdown]
# # Decision Tree

# %%
#import sys
#!{sys.executable} -m pip install pydotplus 

import sys
# !{sys.executable} -m pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.7/site-packages (0.14.1)
# Requirement already satisfied: pydotplus in /opt/conda/lib/python3.7/site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in /opt/conda/lib/python3.7/site-packages (from pydotplus) (2.4.7)

# %%
import pandas
from sklearn import tree
import pydotplus
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

df = pandas.read_csv("shows.csv")

print(df)
# Out:
#     Age  Experience  Rank Nationality   Go
# 0    36          10     9          UK   NO
# 1    42          12     4         USA   NO
# 2    23           4     6           N   NO
# 3    52           4     4         USA   NO
# 4    43          21     8         USA  YES
# 5    44          14     5          UK   NO
# 6    66           3     7           N  YES
# 7    35          14     9          UK  YES
# 8    52          13     7           N  YES
# 9    35           5     9           N  YES
# 10   24           3     5         USA   NO
# 11   18           3     7          UK  YES
# 12   45           9     9          UK  YES

# %%
#Change string values into numerical values

d = {'UK': 0, 'USA': 1, 'N': 2}
df['Nationality'] = df['Nationality'].map(d)
d = {'YES': 1, 'NO': 0}
df['Go'] = df['Go'].map(d)

print(df)
# Out:
#     Age  Experience  Rank  Nationality  Go
# 0    36          10     9            0   0
# 1    42          12     4            1   0
# 2    23           4     6            2   0
# 3    52           4     4            1   0
# 4    43          21     8            1   1
# 5    44          14     5            0   0
# 6    66           3     7            2   1
# 7    35          14     9            0   1
# 8    52          13     7            2   1
# 9    35           5     9            2   1
# 10   24           3     5            1   0
# 11   18           3     7            0   1
# 12   45           9     9            0   1

# %%
#X is the feature columns, y is the target column

features = ['Age', 'Experience', 'Rank', 'Nationality']

X = df[features]
y = df['Go']

print(X)
print(y)
# Out:
#     Age  Experience  Rank  Nationality
# 0    36          10     9            0
# 1    42          12     4            1
# 2    23           4     6            2
# 3    52           4     4            1
# 4    43          21     8            1
# 5    44          14     5            0
# 6    66           3     7            2
# 7    35          14     9            0
# 8    52          13     7            2
# 9    35           5     9            2
# 10   24           3     5            1
# 11   18           3     7            0
# 12   45           9     9            0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     1
# 9     1
# 10    0
# 11    1
# 12    1
# Name: Go, dtype: int64
